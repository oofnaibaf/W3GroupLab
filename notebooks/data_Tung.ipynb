# %%
import pandas as pd
import statistics
import matplotlib.pyplot as plt

# %%
housing = pd.read_excel("../data/raw/week_3_project_data.xlsx", sheet_name=0)
housing
# Out:
#   Unnamed: 0    2019    2020    2021    2022    2023
# 0         DE  128.70  138.70  154.80  162.60  148.80
# 1         FR  110.86  116.62  123.98  131.82  131.26
# 2         PT  141.88  154.33  168.84  190.17  205.76

# %%
housing = housing.rename(columns = {"Unnamed: 0": "Country"})
housing
# Out:
#   Country    2019    2020    2021    2022    2023
# 0      DE  128.70  138.70  154.80  162.60  148.80
# 1      FR  110.86  116.62  123.98  131.82  131.26
# 2      PT  141.88  154.33  168.84  190.17  205.76

# %%
rental = pd.read_excel("../data/raw/week_3_project_data.xlsx", sheet_name=1)
rental
# Out:
#   Unnamed: 0    2019    2020    2021    2022    2023
# 0         DE  100.67  101.06  101.92  102.60  104.78
# 1         FR  107.97  110.76  101.92  115.79  121.05
# 2         PT  106.10  107.60  109.00  110.80  113.10

# %%
rental = rental.rename(columns = {"Unnamed: 0": "Country"})
rental
# Out:
#   Country    2019    2020    2021    2022    2023
# 0      DE  100.67  101.06  101.92  102.60  104.78
# 1      FR  107.97  110.76  101.92  115.79  121.05
# 2      PT  106.10  107.60  109.00  110.80  113.10

# %%
income = pd.read_excel("../data/raw/week_3_project_data.xlsx", sheet_name=2)
income
# Out:
#   Unnamed: 0   2019   2020   2021   2022   2023
# 0         DE  26105  29896  29106  28569  30308
# 1         FR  26210  25382  26075  26419  27577
# 2         PT  11786  12696  13113  13148  14368

# %%
income = income.rename(columns = {"Unnamed: 0" : "Country"})
income
# Out:
#   Country   2019   2020   2021   2022   2023
# 0      DE  26105  29896  29106  28569  30308
# 1      FR  26210  25382  26075  26419  27577
# 2      PT  11786  12696  13113  13148  14368

# %%
total = housing.merge(rental, on = "Country", how = "inner")
total
# Out:
#   Country  2019_x  2020_x  2021_x  2022_x  2023_x  2019_y  2020_y  2021_y  \
# 0      DE  128.70  138.70  154.80  162.60  148.80  100.67  101.06  101.92
# 1      FR  110.86  116.62  123.98  131.82  131.26  107.97  110.76  101.92
# 2      PT  141.88  154.33  168.84  190.17  205.76  106.10  107.60  109.00
#
#    2022_y  2023_y
# 0  102.60  104.78
# 1  115.79  121.05
# 2  110.80  113.10

# %%
countries = pd.read_excel("../data/raw/Numbeo stats.xlsx")
countries
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 countries = pd.read_excel("https://docs.google.com/spreadsheets/d/1Gom_CeDVlEMrCsWxHQcTJ8fCq5d_T7sf2LfEHRF3EEk/edit?gid=1004792292#gid=1004792292")
#       2 countries
#
# File ~\Desktop\_IRONHACK\Module_1\MiniProjects\Week3\W3GroupLab\.venv\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
# ...
